# %%
import pathlib
import pandas as pd
import re
import numpy as np
from collections import Counter
from fuzzywuzzy import fuzz

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read data and extract table company - true_utes

# %%
# Read xlsx from Enrique
df_checks = pd.read_excel("../data/ejemplos_enrique.xlsx")
df_checks
# Out:
#      Unnamed: 0          Nº EXPEDIENTE  \
# 0           1.0  300/2021/00680 LOTE 1
# 1           NaN                    NaN
# 2           NaN                    NaN
# 3           NaN                    NaN
# 4           NaN                    NaN
# ..          ...                    ...
# 98          NaN                    NaN
# 99          NaN                    NaN
# 100         NaN                    NaN
# 101        18.0         300/2021/00569
# 102         NaN                    NaN
#
#                                    TÍTULO DEL CONTRATO  \
# 0    PRESTACIÓN DE SERVICIOS PARA LA PUESTA EN MARC...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101  “DISEÑO Y PUESTA EN MARCHA DE UN\nLABORATORIO ...
# 102                                                NaN
#
#                    EMPRESAS PARTICIPANTES RAZÓN SOCIAL         NIF  \
# 0                                 GLOBAL INCUBFATOR SL   B85432037
# 1    UTE TYPSA, ESTADÍSTICA Y SERVICIOS SLU Y MAGIC...  TEMP 09454
# 2                                                  NaN         NaN
# 3                             UTE VODAFONE ESPAÑA, SAU   U72479678
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 98                            SERLINGO SOCIAL, S.L.U.    B86868593
# 99                    TREBOL INTEGRACION SOCIAL, S.L.    B82349457
# 100                                                NaN         NaN
# 101  FUNDACION JUAN XXIII-RONCALLI PARA LA DISCAPAC...   G78280880
# 102                SM SISTEMAS MEDIOAMBIENTALES, S.L.    B61461810
#
#         EMPRESAS QUE LICITAN EN UTE NIF COMPONENTES UTE PYME  \
# 0                               NaN                 NaN   SI
# 1    TÉCNICA Y PROYECTOS SA (TYPSA)           A28171288   NO
# 2                   MAGIC FENNEC SL           B99550667   SI
# 3               VODAFONE ESPAÑA SAU           A80907397   NO
# 4                    GAMERA NEST SL           B2882956K   SI
# ..                              ...                 ...  ...
# 98                              NaN                 NaN   SÍ
# 99                              NaN                 NaN   SÍ
# 100                             NaN                 NaN  NaN
# 101                             NaN                 NaN   NO
# 102                             NaN                 NaN   SÍ
#
#              ENLACE AL DOCUMENTO ACTA APERTURA SOBRE A  \
# 0    https://contrataciondelestado.es/wps/wcm/conne...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101  https://contrataciondelestado.es/wps/wcm/conne...
# 102                                                NaN
#
#         ACTA SOBRE A                    IDENTIFICA UTE TIPO DE ENTIDAD  \
# 0                                                  NaN         Empresa
# 1    SÍ (Pág 3 "(…) UTE TYPSA ESTADÍSTICA Y SERVICI...         Empresa
# 2                                                  NaN         Empresa
# 3    SÍ (Pág 3 "(…) UTE GAMERA, VODAFONE OWW GAMERS...         Empresa
# 4                                                  NaN         Empresa
# ..                                                 ...             ...
# 98                                                 NaN         Empresa
# 99                                                 NaN         Empresa
# 100                                                NaN             NaN
# 101                                                NaN       Fundación
# 102                                                NaN         Empresa
#
#               TIPO DE SOCIEDAD EMPRESA ADJUDICATARIA   \
# 0                           SL                     NO
# 1                          SLU                     NO
# 2                           SL                    NaN
# 3                          SAU                     SI
# 4                           SL                    NaN
# ..                         ...                    ...
# 98   Centro Especial de Empleo                     NO
# 99   Centro Especial de Empleo                     NO
# 100                        NaN                    NaN
# 101                        NaN                     SÍ
# 102                         SL                     NO
#
#              ENLACE AL DOCUMENTO ANUNCIO FORMALIZACIÓN
# 0    DOC_FORM2023-018297.pdf (contrataciondelestado...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101  https://contrataciondelestado.es/wps/wcm/conne...
# 102                                                NaN
#
# [103 rows x 14 columns]

# %%
# Get compnay and utes
df_checks = df_checks.rename(columns={
    "EMPRESAS PARTICIPANTES RAZÓN SOCIAL": "utes",
    "EMPRESAS QUE LICITAN EN UTE": "company"
})[["utes", "company"]]
df_checks
# Out:
#                                                   utes  \
# 0                                 GLOBAL INCUBFATOR SL
# 1    UTE TYPSA, ESTADÍSTICA Y SERVICIOS SLU Y MAGIC...
# 2                                                  NaN
# 3                             UTE VODAFONE ESPAÑA, SAU
# 4                                                  NaN
# ..                                                 ...
# 98                            SERLINGO SOCIAL, S.L.U.
# 99                    TREBOL INTEGRACION SOCIAL, S.L.
# 100                                                NaN
# 101  FUNDACION JUAN XXIII-RONCALLI PARA LA DISCAPAC...
# 102                SM SISTEMAS MEDIOAMBIENTALES, S.L.
#
#                             company
# 0                               NaN
# 1    TÉCNICA Y PROYECTOS SA (TYPSA)
# 2                   MAGIC FENNEC SL
# 3               VODAFONE ESPAÑA SAU
# 4                    GAMERA NEST SL
# ..                              ...
# 98                              NaN
# 99                              NaN
# 100                             NaN
# 101                             NaN
# 102                             NaN
#
# [103 rows x 2 columns]

# %%
# Get name of utes that went to nan after convesion from excel
for index, row in df_checks.iterrows():
    if pd.isna(row["utes"]):
        row["utes"] = df_checks.iloc[index-1].utes
        
# We do not consider ute/compnay pairs with nan value in compnay
df_checks = df_checks.dropna()

# Save utes in a list for processing with our methids
utes_found = df_checks.utes.unique().tolist()

# Create a new dataframe where for each company, we have a list with the utes in which it has participated
new_df_checks = df_checks.groupby('company')['utes'].apply(list).reset_index()
new_df_checks.columns = ['company', 'true_utes']

# Extract list of companies
companies_list = new_df_checks.company.values.tolist()

new_df_checks
# Out:
#                                               company  \
# 0            ADD4U SOLUCIONES PARA EL DESARROLLO S.L.
# 1      ADD4U SOLUCIONES PARA GESTION Y DESARROLLO SL.
# 2                              ALTRAPO LAB S COOP MAD
# 3               ARACAS DE MANTENIMIENTO INTEGRAL S.A.
# 4               ARACAS MANTENIMIENTO Y SERVICIO, S.L.
# 5                                BEL CONSULTORES S.L.
# 6     CONSTRUCCIONES FRANCISCO CARRASCO NOVILLO, S.A
# 7                           CROWE ACCELERA MANAGEMENT
# 8             FERNÁNDEZ MOLINA OBRAS Y SERVICIOS S.A.
# 9              FUNDACION DELEGACIÓN FUNDACIÓN FINNOVA
# 10    FUNDACIÓN CIDEAL DE COOPERACIÓN E INVESTIGACIÓN
# 11             FUNDACIÓN DELEGACIÓN FUNDACIÓN FINNOVA
# 12                                     GAMERA NEST SL
# 13   GESOR, GESTIÓN Y ORGANIZACIÓN PARA EMPRESAS S.L.
# 14                           HOLISTIC STRATEGIES S.L.
# 15          INICIATIVAS SOCIOAMBIENTALES G.S.COOP MAD
# 16                                    INNOVA NEXT SLU
# 17  LIGHTHOUSE DISRUPTIVE INNOVATION GROUP EUROPE ...
# 18                                    MAGIC FENNEC SL
# 19                                      NOVADAYS S.L.
# 20                             ORIGEN WORLLD WIDE SLU
# 21                                     RPM RACING SLU
# 22                             SACYR SERVICIOS S.A.U.
# 23                      SANHER OBRAS Y PROYECTOS S.L.
# 24              SCIENCE & INNOVATION LINK OFFICE S.L.
# 25  SECTOR 3, INFORMACIÓN Y SERVICIOS PARA EL TERC...
# 26                 SG DE RAEE Y PILAS S.L (RECZYCLIA)
# 27                SG DE RAEE Y PILAS S.L. (RECZYCLIA)
# 28                        SOC COOP MAD INDAGA RSEARCH
# 29            SPAIN INVEST PROFESSIONAL SERVICES S.L.
# 30                            TEAM RANDOMK ESPORTS SL
# 31                                       TRAUXIA S.A.
# 32                     TÉCNICA Y PROYECTOS SA (TYPSA)
# 33                        UNIVERSIDAD REY JUAN CARLOS
# 34                                                UPM
# 35                                VODAFONE ESPAÑA SAU
#
#                                             true_utes
# 0                 [UTE HOLISTIC - LIGHTHOUSE - ADD4U]
# 1                                 [UTE ADD4U - SIFDI]
# 2                                [UTE PIC FUENCARRAL]
# 3   [UTE ARACAS DE MANTENIMIENTO INTEGRAL S.A - AR...
# 4   [UTE ARACAS DE MANTENIMIENTO INTEGRAL S.A - AR...
# 5   [UTE LICITACIONES BEL CONSULTORES S.L. - FUNDA...
# 6   [UTE CONSTRUCCIONES FRANCISCO CARRASCO NOVILLO...
# 7   [UTE  UNIVERSIDAD REY JUAN CARLOS - CROWE ACEL...
# 8   [UTE CONSTRUCCIONES FRANCISCO CARRASCO NOVILLO...
# 9   [UTE FUNDACION DELEGACIÓN FUNDACIÓN FINNOVA - ...
# 10  [UTE LICITACIONES BEL CONSULTORES S.L. - FUNDA...
# 11  [UTE FUNDACIÓN DELEGACIÓN FUNDACIÓN FINNOVA - ...
# 12                         [UTE VODAFONE ESPAÑA, SAU]
# 13  [UTE LICITACIONES BEL CONSULTORES S.L. - FUNDA...
# 14                [UTE HOLISTIC - LIGHTHOUSE - ADD4U]
# 15                               [UTE PIC FUENCARRAL]
# 16                       [UTE INNOVA NEXT SLU - UPM ]
# 17                [UTE HOLISTIC - LIGHTHOUSE - ADD4U]
# 18  [UTE TYPSA, ESTADÍSTICA Y SERVICIOS SLU Y MAGI...
# 19                               [UTE SILO-NOVADAYS ]
# 20                         [UTE VODAFONE ESPAÑA, SAU]
# 21     [UTE RPM RACING SLU - TEAM RANDOMK ESPORTS SL]
# 22                    [UTE SACYR SERVICIOS SAU - UPM]
# 23  [UTE TRAUXIA, S.A. - SANHER OBRAS Y PROYECTOS,...
# 24                               [UTE SILO-NOVADAYS ]
# 25  [UTE LICITACIONES BEL CONSULTORES S.L. - FUNDA...
# 26  [UTE FUNDACIÓN DELEGACIÓN FUNDACIÓN FINNOVA - ...
# 27  [UTE FUNDACION DELEGACIÓN FUNDACIÓN FINNOVA - ...
# 28                               [UTE PIC FUENCARRAL]
# 29                                [UTE ADD4U - SIFDI]
# 30     [UTE RPM RACING SLU - TEAM RANDOMK ESPORTS SL]
# 31  [UTE TRAUXIA, S.A. - SANHER OBRAS Y PROYECTOS,...
# 32  [UTE TYPSA, ESTADÍSTICA Y SERVICIOS SLU Y MAGI...
# 33  [UTE  UNIVERSIDAD REY JUAN CARLOS - CROWE ACEL...
# 34  [UTE INNOVA NEXT SLU - UPM , UTE SACYR SERVICI...
# 35                         [UTE VODAFONE ESPAÑA, SAU]

# %% [markdown]
# ## Get lists of stops

# %%
df_company = pd.read_parquet("../data/company_info.parquet")
SEPS_UTES = (df_company.CompanyType.unique().tolist() +
             ["s.l.p.", "s.l.p", "s.l.l.", "s.a.u.", "s.l.u.", "s.l.u", "s.l.u,", "slu", "s.l", "c.o.o.p.", "s.a", "sl.", "sccl", "s.coop.pequeña"] +
             ["sl", "slu", "s.", "scclp"])[1:]

OTHERS = ["-", "_", ",", "+", ".", ".,"]
SEPS = SEPS_UTES + OTHERS

# %%
path_aux = pathlib.Path("metalists")

# %%
########################################################################
# Create lists of common names/last names in Spain and broadcast them
########################################################################
path_apellidos = path_aux / "apellidos.parquet"
path_nombres = path_aux / "nombres.parquet"

# Read Parquet files into Pandas DataFrames
df_appellidos = pd.read_parquet(path_apellidos)
df_nombres = pd.read_parquet(path_nombres)

# Apply transformation to divide composed names into new items
df_appellidos['palabras'] = df_appellidos['apellidos'].str.split(" ")
df_appellidos = df_appellidos.explode('palabras').rename(columns={'palabras': 'apellidos'})

df_nombres['palabras'] = df_nombres['nombres'].str.split(" ")
df_nombres = df_nombres.explode('palabras').rename(columns={'palabras': 'nombres'})

# Collect the unique names and last names
unique_apellidos = df_appellidos['apellidos'].values.tolist()
unique_names = df_nombres['nombres'].values.tolist()
UNIQUE_NAMES_APELLIDOS = np.unique(np.concatenate((unique_names, unique_apellidos))).tolist()
UNIQUE_NAMES_APELLIDOS.sort()

# %%
########################################################################
# Create list of common spanish and catalan words
########################################################################
with open(path_aux.joinpath("es.txt")) as file:
    COMMON_SPANISH = file.readlines()
    COMMON_SPANISH = [line.rstrip() for line in COMMON_SPANISH]
with open(path_aux.joinpath("catalan.txt")) as file:
    COMMON_CATALAN = file.readlines()
    COMMON_CATALAN = [line.rstrip() for line in COMMON_CATALAN]

########################################################################
# We also laod a list of words generated from the "splits" of the company names obtained from a previous execution of this script that have a frequency larger than the 95th percentile of the frequency distribution of the "splits" of the company names
########################################################################
with open(path_aux.joinpath("filtered_elements.txt")) as file:
    SPLITS_STOPS = file.readlines()
    SPLITS_STOPS = [line.rstrip() for line in SPLITS_STOPS]

# %%
# GLOBAL VARIABLES
re_pattern = re.compile(r'([.,!?;:\s()-])')
TRANS_TABLE = str.maketrans('áéíóúÁÉÍÓÚòÒ', 'aeiouAEIOUoO')
def remove_punctuation(
    name: str
) -> str:
    """Remove punctuation and accents from a string.

    Parameters
    ----------
    name : str
        The name of the company.

    Returns
    -------
    str
        The name of the company without punctuation and accents.
    """
    return name.translate(TRANS_TABLE)

def remove_punctuation_list(
    name: str
) -> str:
    return [remove_punctuation(el) for el in name]

def find_substring_similar(
    main_string: str,
    substring: str,
    substring_splits: list,
    threshold: int = 95
) -> bool:
    """
    Given the name of an UTE (main_string), that of a company (substring), and the "splits" of the company name (i.e. a list of the words that compose the company name, after filtering out some terms), it first try to find the substring within the main_string with a similarity ratio larger than a threshold. If it does not find it, it checks for partial matches with some punctuation separation.

    Parameters
    ----------
    main_string : str
        The name of the UTE.
    substring : str
        The name of the company.
    substring_splits : list
        The "splits" of the company name, after filtering out some terms.
    threshold : int
        The threshold for the similarity ratio. The default is 95.

    Returns
    -------
    bool
        Whether the substring is found within the main_string with a similarity ratio larger than a threshold or not.
    """

    ############################################################################
    # Check for exact matches
    ############################################################################
    regex_pattern = r'\b' + re.escape(substring) + r'\b'
    regex = re.compile(regex_pattern)

    len_substring = len(substring)
    for match in regex.finditer(main_string):
        start_index = match.start()
        end_index = match.end()

        # Calculate similarity only for substrings around the match
        for i in range(start_index, end_index - len_substring + 1):
            sub = main_string[i:i + len_substring]
            similitud = fuzz.ratio(sub, substring)
            if similitud >= threshold:
                return True

    ############################################################################
    # Check for partial matches with some punctuation separation
    ############################################################################
    if re.search(r'[.,!?;:\s()-]', main_string):
        main_string_split = set(
            re.split(r'([.,!?;:\s()-])', main_string.lower()))
        # if any(len(split) > 3 and split in main_string_split for split in substring_splits):
        substring_set = set(substring_splits)

        if len(main_string_split.intersection(substring_set)) >= 1:
            return True
        
def get_splits(
    name: str
) -> list:
    """Split the name of a company into its parts, after filtering out some terms.

    The terms that are filtered out are:
    - Words with less than 3 characters.
    - Numbers.
    - Common words in Spanish and Catalan (extracted from the files "es.txt" and "catalan.txt").
    - Common last names and names in Spain (extracted from the files "apellidos.parquet" and "nombres.parquet").
    - Common words obtained from the "splits" of the company names that have a frequency larger than the 95th percentile of the frequency distribution of the "splits" of the company names (extracted from the file "filtered_elements.txt").

    Parameters
    ----------
    name : str
        The name of the company.

    Returns
    -------
    list
        The parts of the name of the company, after filtering out some terms.
    """
    if re_pattern.search(name):
        name_parts = re_pattern.split(name.lower())
        # Remove empty strings, separators, and duplicates
        name_parts = [part.strip(',').strip()
                      for part in name_parts
                      if part.strip()
                      and len(part) > 3
                      and not part.isdigit()
                      and not part in SEPS
                      and not part in (UNIQUE_NAMES_APELLIDOS + COMMON_SPANISH + COMMON_CATALAN + SPLITS_STOPS)
                     ]
        return name_parts if len(name_parts) > 0 else []
    return []

def get_company_utes(name, splits):
    aux = [fullName for fullName in unique_names if find_substring_similar(fullName, name, splits)]
    
    return list(set(aux))

# %%
new_df_checks["company_norm"] = new_df_checks["company"].apply(remove_punctuation)
new_df_checks["true_utes_norm"] = new_df_checks["true_utes"].apply(remove_punctuation_list)
new_df_checks["splits"] = new_df_checks["company_norm"].apply(get_splits)

# %%
path_utes = pathlib.Path("../data/utes.parquet")
df_utes = pd.read_parquet(path_utes)
df_utes["FullName_norm"] = df_utes["FullName"].apply(remove_punctuation)
#unique_names = df_utes.FullName_norm.unique().tolist()

def flatten(xss):
    return [x for xs in xss for x in xs]
unique_names = flatten(new_df_checks.true_utes_norm.values.tolist())

# %%
new_df_checks['utes'] = new_df_checks.apply(
    lambda row: get_company_utes(row['company_norm'], row["splits"]), axis=1)

# %%
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                      'display.max_colwidth',None):
    display(new_df_checks)
# Out:
#                                                          company  \
# 0                       ADD4U SOLUCIONES PARA EL DESARROLLO S.L.
# 1                 ADD4U SOLUCIONES PARA GESTION Y DESARROLLO SL.
# 2                                         ALTRAPO LAB S COOP MAD
# 3                          ARACAS DE MANTENIMIENTO INTEGRAL S.A.
# 4                          ARACAS MANTENIMIENTO Y SERVICIO, S.L.
# 5                                           BEL CONSULTORES S.L.
# 6                CONSTRUCCIONES FRANCISCO CARRASCO NOVILLO, S.A
# 7                                      CROWE ACCELERA MANAGEMENT
# 8                        FERNÁNDEZ MOLINA OBRAS Y SERVICIOS S.A.
# 9                         FUNDACION DELEGACIÓN FUNDACIÓN FINNOVA
# 10               FUNDACIÓN CIDEAL DE COOPERACIÓN E INVESTIGACIÓN
# 11                        FUNDACIÓN DELEGACIÓN FUNDACIÓN FINNOVA
# 12                                                GAMERA NEST SL
# 13              GESOR, GESTIÓN Y ORGANIZACIÓN PARA EMPRESAS S.L.
# 14                                      HOLISTIC STRATEGIES S.L.
# 15                     INICIATIVAS SOCIOAMBIENTALES G.S.COOP MAD
# 16                                               INNOVA NEXT SLU
# 17            LIGHTHOUSE DISRUPTIVE INNOVATION GROUP EUROPE S.L.
# 18                                               MAGIC FENNEC SL
# 19                                                 NOVADAYS S.L.
# 20                                        ORIGEN WORLLD WIDE SLU
# 21                                                RPM RACING SLU
# 22                                        SACYR SERVICIOS S.A.U.
# 23                                 SANHER OBRAS Y PROYECTOS S.L.
# 24                         SCIENCE & INNOVATION LINK OFFICE S.L.
# 25  SECTOR 3, INFORMACIÓN Y SERVICIOS PARA EL TERCER SECTOR S.L.
# 26                            SG DE RAEE Y PILAS S.L (RECZYCLIA)
# 27                           SG DE RAEE Y PILAS S.L. (RECZYCLIA)
# 28                                   SOC COOP MAD INDAGA RSEARCH
# 29                       SPAIN INVEST PROFESSIONAL SERVICES S.L.
# 30                                       TEAM RANDOMK ESPORTS SL
# 31                                                  TRAUXIA S.A.
# 32                                TÉCNICA Y PROYECTOS SA (TYPSA)
# 33                                   UNIVERSIDAD REY JUAN CARLOS
# 34                                                           UPM
# 35                                           VODAFONE ESPAÑA SAU
#
#                                                                                                true_utes  \
# 0                                                                    [UTE HOLISTIC - LIGHTHOUSE - ADD4U]
# 1                                                                                    [UTE ADD4U - SIFDI]
# 2                                                                                   [UTE PIC FUENCARRAL]
# 3                      [UTE ARACAS DE MANTENIMIENTO INTEGRAL S.A - ARACAS MANTENIMIENTO Y SERVICIO S.L.]
# 4                      [UTE ARACAS DE MANTENIMIENTO INTEGRAL S.A - ARACAS MANTENIMIENTO Y SERVICIO S.L.]
# 5   [UTE LICITACIONES BEL CONSULTORES S.L. - FUNDACIÓN CIDEAL - SECTOR 3 INFORMACIÓN Y SERVICIO - GESOR]
# 6                    [UTE CONSTRUCCIONES FRANCISCO CARRASCO NOVILLO, S.A. - OBRAS Y SERVICIOS F. MOLINA]
# 7                                          [UTE  UNIVERSIDAD REY JUAN CARLOS - CROWE ACELERA MANAGEMENT]
# 8                    [UTE CONSTRUCCIONES FRANCISCO CARRASCO NOVILLO, S.A. - OBRAS Y SERVICIOS F. MOLINA]
# 9                                               [UTE FUNDACION DELEGACIÓN FUNDACIÓN FINNOVA - RECZYCLIA]
# 10  [UTE LICITACIONES BEL CONSULTORES S.L. - FUNDACIÓN CIDEAL - SECTOR 3 INFORMACIÓN Y SERVICIO - GESOR]
# 11                                              [UTE FUNDACIÓN DELEGACIÓN FUNDACIÓN FINNOVA - RECZYCLIA]
# 12                                                                            [UTE VODAFONE ESPAÑA, SAU]
# 13  [UTE LICITACIONES BEL CONSULTORES S.L. - FUNDACIÓN CIDEAL - SECTOR 3 INFORMACIÓN Y SERVICIO - GESOR]
# 14                                                                   [UTE HOLISTIC - LIGHTHOUSE - ADD4U]
# 15                                                                                  [UTE PIC FUENCARRAL]
# 16                                                                          [UTE INNOVA NEXT SLU - UPM ]
# 17                                                                   [UTE HOLISTIC - LIGHTHOUSE - ADD4U]
# 18                                            [UTE TYPSA, ESTADÍSTICA Y SERVICIOS SLU Y MAGIC FENNEC SL]
# 19                                                                                  [UTE SILO-NOVADAYS ]
# 20                                                                            [UTE VODAFONE ESPAÑA, SAU]
# 21                                                        [UTE RPM RACING SLU - TEAM RANDOMK ESPORTS SL]
# 22                                                                       [UTE SACYR SERVICIOS SAU - UPM]
# 23                                                  [UTE TRAUXIA, S.A. - SANHER OBRAS Y PROYECTOS, S.L.]
# 24                                                                                  [UTE SILO-NOVADAYS ]
# 25  [UTE LICITACIONES BEL CONSULTORES S.L. - FUNDACIÓN CIDEAL - SECTOR 3 INFORMACIÓN Y SERVICIO - GESOR]
# 26                                              [UTE FUNDACIÓN DELEGACIÓN FUNDACIÓN FINNOVA - RECZYCLIA]
# 27                                              [UTE FUNDACION DELEGACIÓN FUNDACIÓN FINNOVA - RECZYCLIA]
# 28                                                                                  [UTE PIC FUENCARRAL]
# 29                                                                                   [UTE ADD4U - SIFDI]
# 30                                                        [UTE RPM RACING SLU - TEAM RANDOMK ESPORTS SL]
# 31                                                  [UTE TRAUXIA, S.A. - SANHER OBRAS Y PROYECTOS, S.L.]
# 32                                            [UTE TYPSA, ESTADÍSTICA Y SERVICIOS SLU Y MAGIC FENNEC SL]
# 33                                         [UTE  UNIVERSIDAD REY JUAN CARLOS - CROWE ACELERA MANAGEMENT]
# 34                                           [UTE INNOVA NEXT SLU - UPM , UTE SACYR SERVICIOS SAU - UPM]
# 35                                                                            [UTE VODAFONE ESPAÑA, SAU]
#
#                                                     company_norm  \
# 0                       ADD4U SOLUCIONES PARA EL DESARROLLO S.L.
# 1                 ADD4U SOLUCIONES PARA GESTION Y DESARROLLO SL.
# 2                                         ALTRAPO LAB S COOP MAD
# 3                          ARACAS DE MANTENIMIENTO INTEGRAL S.A.
# 4                          ARACAS MANTENIMIENTO Y SERVICIO, S.L.
# 5                                           BEL CONSULTORES S.L.
# 6                CONSTRUCCIONES FRANCISCO CARRASCO NOVILLO, S.A
# 7                                      CROWE ACCELERA MANAGEMENT
# 8                        FERNANDEZ MOLINA OBRAS Y SERVICIOS S.A.
# 9                         FUNDACION DELEGACION FUNDACION FINNOVA
# 10               FUNDACION CIDEAL DE COOPERACION E INVESTIGACION
# 11                        FUNDACION DELEGACION FUNDACION FINNOVA
# 12                                                GAMERA NEST SL
# 13              GESOR, GESTION Y ORGANIZACION PARA EMPRESAS S.L.
# 14                                      HOLISTIC STRATEGIES S.L.
# 15                     INICIATIVAS SOCIOAMBIENTALES G.S.COOP MAD
# 16                                               INNOVA NEXT SLU
# 17            LIGHTHOUSE DISRUPTIVE INNOVATION GROUP EUROPE S.L.
# 18                                               MAGIC FENNEC SL
# 19                                                 NOVADAYS S.L.
# 20                                        ORIGEN WORLLD WIDE SLU
# 21                                                RPM RACING SLU
# 22                                        SACYR SERVICIOS S.A.U.
# 23                                 SANHER OBRAS Y PROYECTOS S.L.
# 24                         SCIENCE & INNOVATION LINK OFFICE S.L.
# 25  SECTOR 3, INFORMACION Y SERVICIOS PARA EL TERCER SECTOR S.L.
# 26                            SG DE RAEE Y PILAS S.L (RECZYCLIA)
# 27                           SG DE RAEE Y PILAS S.L. (RECZYCLIA)
# 28                                   SOC COOP MAD INDAGA RSEARCH
# 29                       SPAIN INVEST PROFESSIONAL SERVICES S.L.
# 30                                       TEAM RANDOMK ESPORTS SL
# 31                                                  TRAUXIA S.A.
# 32                                TECNICA Y PROYECTOS SA (TYPSA)
# 33                                   UNIVERSIDAD REY JUAN CARLOS
# 34                                                           UPM
# 35                                           VODAFONE ESPAÑA SAU
#
#                                                                                           true_utes_norm  \
# 0                                                                    [UTE HOLISTIC - LIGHTHOUSE - ADD4U]
# 1                                                                                    [UTE ADD4U - SIFDI]
# 2                                                                                   [UTE PIC FUENCARRAL]
# 3                      [UTE ARACAS DE MANTENIMIENTO INTEGRAL S.A - ARACAS MANTENIMIENTO Y SERVICIO S.L.]
# 4                      [UTE ARACAS DE MANTENIMIENTO INTEGRAL S.A - ARACAS MANTENIMIENTO Y SERVICIO S.L.]
# 5   [UTE LICITACIONES BEL CONSULTORES S.L. - FUNDACION CIDEAL - SECTOR 3 INFORMACION Y SERVICIO - GESOR]
# 6                    [UTE CONSTRUCCIONES FRANCISCO CARRASCO NOVILLO, S.A. - OBRAS Y SERVICIOS F. MOLINA]
# 7                                          [UTE  UNIVERSIDAD REY JUAN CARLOS - CROWE ACELERA MANAGEMENT]
# 8                    [UTE CONSTRUCCIONES FRANCISCO CARRASCO NOVILLO, S.A. - OBRAS Y SERVICIOS F. MOLINA]
# 9                                               [UTE FUNDACION DELEGACION FUNDACION FINNOVA - RECZYCLIA]
# 10  [UTE LICITACIONES BEL CONSULTORES S.L. - FUNDACION CIDEAL - SECTOR 3 INFORMACION Y SERVICIO - GESOR]
# 11                                              [UTE FUNDACION DELEGACION FUNDACION FINNOVA - RECZYCLIA]
# 12                                                                            [UTE VODAFONE ESPAÑA, SAU]
# 13  [UTE LICITACIONES BEL CONSULTORES S.L. - FUNDACION CIDEAL - SECTOR 3 INFORMACION Y SERVICIO - GESOR]
# 14                                                                   [UTE HOLISTIC - LIGHTHOUSE - ADD4U]
# 15                                                                                  [UTE PIC FUENCARRAL]
# 16                                                                          [UTE INNOVA NEXT SLU - UPM ]
# 17                                                                   [UTE HOLISTIC - LIGHTHOUSE - ADD4U]
# 18                                            [UTE TYPSA, ESTADISTICA Y SERVICIOS SLU Y MAGIC FENNEC SL]
# 19                                                                                  [UTE SILO-NOVADAYS ]
# 20                                                                            [UTE VODAFONE ESPAÑA, SAU]
# 21                                                        [UTE RPM RACING SLU - TEAM RANDOMK ESPORTS SL]
# 22                                                                       [UTE SACYR SERVICIOS SAU - UPM]
# 23                                                  [UTE TRAUXIA, S.A. - SANHER OBRAS Y PROYECTOS, S.L.]
# 24                                                                                  [UTE SILO-NOVADAYS ]
# 25  [UTE LICITACIONES BEL CONSULTORES S.L. - FUNDACION CIDEAL - SECTOR 3 INFORMACION Y SERVICIO - GESOR]
# 26                                              [UTE FUNDACION DELEGACION FUNDACION FINNOVA - RECZYCLIA]
# 27                                              [UTE FUNDACION DELEGACION FUNDACION FINNOVA - RECZYCLIA]
# 28                                                                                  [UTE PIC FUENCARRAL]
# 29                                                                                   [UTE ADD4U - SIFDI]
# 30                                                        [UTE RPM RACING SLU - TEAM RANDOMK ESPORTS SL]
# 31                                                  [UTE TRAUXIA, S.A. - SANHER OBRAS Y PROYECTOS, S.L.]
# 32                                            [UTE TYPSA, ESTADISTICA Y SERVICIOS SLU Y MAGIC FENNEC SL]
# 33                                         [UTE  UNIVERSIDAD REY JUAN CARLOS - CROWE ACELERA MANAGEMENT]
# 34                                           [UTE INNOVA NEXT SLU - UPM , UTE SACYR SERVICIOS SAU - UPM]
# 35                                                                            [UTE VODAFONE ESPAÑA, SAU]
#
#                                           splits  \
# 0                                        [add4u]
# 1                                        [add4u]
# 2                                [altrapo, coop]
# 3                                       [aracas]
# 4                                       [aracas]
# 5                                             []
# 6                                             []
# 7                                     [accelera]
# 8                                             []
# 9                                      [finnova]
# 10                                      [cideal]
# 11                                     [finnova]
# 12                                [gamera, nest]
# 13                                       [gesor]
# 14                        [holistic, strategies]
# 15                      [socioambientales, coop]
# 16                                        [next]
# 17  [lighthouse, disruptive, innovation, europe]
# 18                               [magic, fennec]
# 19                                    [novadays]
# 20                                [worlld, wide]
# 21                                      [racing]
# 22                                       [sacyr]
# 23                                      [sanher]
# 24                   [science, innovation, link]
# 25                                            []
# 26                             [raee, reczyclia]
# 27                             [raee, reczyclia]
# 28                               [coop, rsearch]
# 29                                      [invest]
# 30                                     [randomk]
# 31                                     [trauxia]
# 32                                       [typsa]
# 33                                            []
# 34                                            []
# 35                                    [vodafone]
#
#                                                                                                     utes
# 0                                                 [UTE ADD4U - SIFDI, UTE HOLISTIC - LIGHTHOUSE - ADD4U]
# 1                                                 [UTE ADD4U - SIFDI, UTE HOLISTIC - LIGHTHOUSE - ADD4U]
# 2                                                                                                     []
# 3                      [UTE ARACAS DE MANTENIMIENTO INTEGRAL S.A - ARACAS MANTENIMIENTO Y SERVICIO S.L.]
# 4                      [UTE ARACAS DE MANTENIMIENTO INTEGRAL S.A - ARACAS MANTENIMIENTO Y SERVICIO S.L.]
# 5                                                                                                     []
# 6                                                                                                     []
# 7                                                                                                     []
# 8                                                                                                     []
# 9                                               [UTE FUNDACION DELEGACION FUNDACION FINNOVA - RECZYCLIA]
# 10  [UTE LICITACIONES BEL CONSULTORES S.L. - FUNDACION CIDEAL - SECTOR 3 INFORMACION Y SERVICIO - GESOR]
# 11                                              [UTE FUNDACION DELEGACION FUNDACION FINNOVA - RECZYCLIA]
# 12                                                                                                    []
# 13  [UTE LICITACIONES BEL CONSULTORES S.L. - FUNDACION CIDEAL - SECTOR 3 INFORMACION Y SERVICIO - GESOR]
# 14                                                                   [UTE HOLISTIC - LIGHTHOUSE - ADD4U]
# 15                                                                                                    []
# 16                                                                          [UTE INNOVA NEXT SLU - UPM ]
# 17                                                                   [UTE HOLISTIC - LIGHTHOUSE - ADD4U]
# 18                                            [UTE TYPSA, ESTADISTICA Y SERVICIOS SLU Y MAGIC FENNEC SL]
# 19                                                                                  [UTE SILO-NOVADAYS ]
# 20                                                                                                    []
# 21                                                        [UTE RPM RACING SLU - TEAM RANDOMK ESPORTS SL]
# 22                                                                       [UTE SACYR SERVICIOS SAU - UPM]
# 23                                                  [UTE TRAUXIA, S.A. - SANHER OBRAS Y PROYECTOS, S.L.]
# 24                                                                                                    []
# 25                                                                                                    []
# 26                                              [UTE FUNDACION DELEGACION FUNDACION FINNOVA - RECZYCLIA]
# 27                                              [UTE FUNDACION DELEGACION FUNDACION FINNOVA - RECZYCLIA]
# 28                                                                                                    []
# 29                                                                                                    []
# 30                                                        [UTE RPM RACING SLU - TEAM RANDOMK ESPORTS SL]
# 31                                                  [UTE TRAUXIA, S.A. - SANHER OBRAS Y PROYECTOS, S.L.]
# 32                                            [UTE TYPSA, ESTADISTICA Y SERVICIOS SLU Y MAGIC FENNEC SL]
# 33                                         [UTE  UNIVERSIDAD REY JUAN CARLOS - CROWE ACELERA MANAGEMENT]
# 34                                           [UTE INNOVA NEXT SLU - UPM , UTE SACYR SERVICIOS SAU - UPM]
# 35                                                                            [UTE VODAFONE ESPAÑA, SAU]
